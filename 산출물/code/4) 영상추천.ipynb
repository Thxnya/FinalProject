# %%
# 유튜브 태그 데이터 수집
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time
doru = requests.get('https://www.youtube.com/watch?v=vN0FUFCXnJM&t=6s')
doru_text = bs(doru.text)


title = doru_text.select_one('meta[itemprop="description"][content]')['content']
doc = doru_text.select_one('meta[name="keywords"][content]')['content']

view = doru_text.select_one('meta[itemprop="interactionCount"][content]')['content']
print(doc)
